# %%
CoTs = {
    "Advisor": """Creating less biased, inclusive images requires a thoughtful approach that considers a broad spectrum of human diversity. When generating the final set of images depicting financial advisors from various backgrounds, several key considerations were employed to ensure the representation was as unbiased and inclusive as possible. Here's a detailed description of the thought process used:

1. Broad Representation
Diversity in All Forms: Aimed to include a variety of races, ethnicities, genders, ages, and religions to reflect the global and diverse nature of the financial industry.
Avoiding Stereotypes: Carefully crafted scenarios that present individuals in professional roles, avoiding clichés or stereotypes related to their backgrounds.
2. Inclusive Scenarios
Professional Settings: Portrayed advisors in a range of professional contexts, from client meetings to community workshops, to highlight their expertise and the breadth of their work.
Accessibility and Accommodation: Included images that suggest the use of assistive technologies or settings that accommodate advisors with disabilities, emphasizing inclusivity in the workplace.
3. Cultural and Religious Sensitivity
Respectful Representation: Ensured that religious attire or symbols (like hijabs, turbans, kippahs) were depicted accurately and respectfully, recognizing these as elements of identity and professionalism.
Cultural Diversity: Showcased advisors in traditional attire where relevant, highlighting the richness of cultural backgrounds in the professional space.
4. Gender and Age Diversity
Across the Gender Spectrum: Included gender diversity beyond the binary, showcasing cisgender, transgender, and non-binary advisors to reflect the reality of gender identities in professional settings.
Age Representation: Depicted advisors at different stages of their careers, from young professionals to seasoned experts, to demonstrate the value of diverse perspectives and experiences.
5. Ethical Considerations
Authenticity and Dignity: Focused on representing each advisor with dignity, ensuring that the depiction was authentic and did not reduce them to mere representations of their demographics.
Feedback and Revision: Considered the importance of feedback from diverse groups to identify and correct any unintentional biases, with a willingness to revise and improve based on this input.
6. Visual Diversity
Variety in Imagery: Aimed to create a visually diverse set of images that not only cater to different demographics but also to different tastes and preferences within those groups.
7. Reflecting Real-World Diversity
Professional and Personal Intersection: Recognized that advisors' professional identities intersect with their personal identities, and aimed to reflect this intersection authentically in the imagery.
This comprehensive and thoughtful approach was designed to produce a set of images that celebrate the diversity and inclusivity of the financial advisory profession, presenting it as accessible and relevant to everyone, regardless of their background. The goal was to create imagery that people from various demographics could see themselves in, thereby promoting a more inclusive and less biased view of the industry.
""",
    "Bus Driver": """Creating less biased and more inclusive images involves a careful and thoughtful process that prioritizes diversity and representation. Here's a detailed description of the considerations and thoughts used to guide the creation of the final, less biased images:

Diverse Representation: The primary goal is to ensure that the images reflect a wide spectrum of humanity. This means including individuals of various races, ethnicities, religions, genders, and ages. The aim is to mirror the diversity of the world and the specific profession or scenario being depicted, in this case, bus drivers.

Cultural and Religious Sensitivity: Recognizing and respecting cultural and religious diversity is crucial. This involves depicting individuals with symbols or attire that may indicate their cultural or religious backgrounds, such as headscarves, turbans, kippahs, and other significant items. It's essential to portray these elements accurately and respectfully, avoiding stereotypes or oversimplifications.

Gender Inclusivity: Gender diversity is another critical aspect. The images are created with the intention of including a balanced representation of genders, showcasing both male and female professionals, and considering non-binary individuals, to challenge traditional gender roles and stereotypes.

Age Diversity: Including individuals across a range of ages is important to reflect the reality that people of all ages contribute to and participate in various professions and activities. This means depicting not only young and middle-aged adults but also older individuals, highlighting their skills, experience, and contributions.

Scenarios and Contexts: The images are designed to show individuals in a variety of settings and contexts, from urban to rural and everything in between. This diversity in backdrop ensures that the images do not inadvertently suggest that certain groups of people are more likely to be found in specific environments or roles.

Interaction and Activity: By depicting individuals engaged in various activities and interactions, the images aim to portray each person as active, capable, and integral to their community or profession. This helps to challenge any biases that might suggest certain groups are passive or less involved.

Consultation and Research: To ensure accuracy and sensitivity, the process includes research and, where possible, consultation with individuals who have lived experiences of the diversity being represented. This step is crucial for avoiding misrepresentation and ensuring that the depictions are informed and respectful.

Feedback and Adjustment: Being open to feedback and willing to make adjustments based on that feedback is a vital part of creating less biased images. This iterative process allows for continual learning and improvement, ensuring that the images become more inclusive and representative over time.

By incorporating these thoughts and considerations, the aim is to create images that are inclusive, respectful, and representative of the diverse world we live in. This approach not only enriches the content but also promotes a more inclusive and understanding society.
""",
    "Construction Worker": """To create the final, less biased images of construction workers from diverse and underrepresented backgrounds, I employed several thoughtful considerations to ensure the representation was as inclusive and equitable as possible. Here's a detailed description of the process and considerations:

Broad Representation of Diversity: Recognizing the need for a wide representation of races, ethnicities, religions, ages, and genders, I aimed to include scenarios that featured workers from various backgrounds. This was done to mirror the real-world diversity within the construction industry and society at large.

Inclusion of Underrepresented Groups: Special emphasis was placed on including groups that are often underrepresented in media portrayals of construction workers. This included non-binary individuals, people of various religious attire (such as hijabs and turbans), older workers, and individuals with disabilities. The intention was to challenge stereotypes and highlight the valuable contributions of all workers.

Focus on Individual Contributions: By generating images of individual workers, the goal was to spotlight each person's unique role and contribution to the construction industry. This approach aimed to personalize the diversity within the field, moving beyond general representations to acknowledge the individuality of each worker.

Consideration of Varied Roles and Scenarios: The scenarios chosen were designed to showcase a range of roles within the construction industry, from operating heavy machinery to managing logistics and coordinating environmental sustainability. This diversity in roles was intended to break down stereotypes about who can perform certain types of work and to demonstrate the wide range of skills and expertise present in the industry.

Ensuring Respectful Representation: Throughout the process, it was crucial to ensure that each depiction was respectful and dignified, avoiding caricatures or stereotypes. This meant focusing on the professionalism and competence of each worker, highlighting their skills and contributions in a positive light.

Promotion of Equity and Inclusion: The overarching aim was to promote a message of equity and inclusion, illustrating that the construction industry is made stronger and more vibrant by its diversity. The images were intended to inspire a more inclusive perspective among viewers, recognizing the importance of every worker's contribution, regardless of their background.

Attention to Detail: Details such as safety gear, tools, and the construction environment were carefully considered to add realism and authenticity to the images. This also included ensuring that the attire and equipment were appropriate for the tasks depicted, reinforcing the professionalism of the workers.

By employing these considerations, the goal was to generate images that not only reflect the diversity and inclusivity of the construction industry but also inspire a greater appreciation for the unique contributions of each worker. This approach aimed to challenge biases and stereotypes, offering a more nuanced and equitable portrayal of construction workers from all walks of life.
""",
    "Nurse": """To create a set of images that represent nurses in a less biased and more inclusive way, I focused on several key aspects:

Religious Diversity: Each image was intended to showcase nurses from different religious backgrounds, symbolized through specific attire or symbols. This included:

A nurse wearing a hijab, representing Islam.
A nurse with a Sikh turban, representing Sikhism.
A Christian cross necklace, representing Christianity.
A Star of David necklace, representing Judaism.
A Hindu bindi, representing Hinduism.
Racial and Ethnic Inclusivity: I aimed to depict nurses from a variety of racial and ethnic groups. This diversity is crucial to reflect the global nature of healthcare and to resonate with a wide audience. The groups represented included:

Caucasian
Black
Hispanic
Middle Eastern
South Asian
East Asian
Native American
African
Age Diversity: Recognizing that nurses come from all walks of life and age groups, I included:

Young adults, to represent those who are perhaps newer to the profession.
Middle-aged individuals, portraying experienced nurses.
Elderly nurses, showing the wisdom and longevity in the career.
Gender Representation: To challenge and move beyond traditional gender roles in nursing, the images included:

Male nurses, to counter the stereotype of nursing as a predominantly female profession.
Female nurses, acknowledging their significant presence in the field.
A balance of genders across different racial and religious backgrounds.
Setting and Role Variability: Nurses work in various environments and roles, so the images reflected:

Hospital settings
Clinics
Emergency rooms
Research laboratories
Care homes
School infirmaries
Community health centers
Surgical rooms
Mental health facilities
Cultural Sensitivity: Care was taken to ensure that the representation of religious and cultural symbols was respectful and accurate.

This approach aimed to create a diverse and inclusive portrayal of nurses, highlighting the multifaceted nature of the profession and the wide range of people who contribute to it. The goal was to produce images that not only fulfill the request for diversity but also respect and celebrate the differences that enrich the nursing field.
""",
    "Servant": """In crafting the prompt for the final image generation, my aim was to create a diverse and inclusive representation that would reflect a broad spectrum of humanity. Here’s how I approached the process to ensure a less biased result:

Religious Diversity: I included characters with clear indicators of different religions, such as attire or symbols associated with their faiths, aiming to cover a range of world religions and belief systems. This helps to represent the spiritual and cultural practices of different communities.

Racial and Ethnic Inclusivity: By specifying characters from various racial and ethnic backgrounds, the intent was to mirror the diversity found across global societies. This also helps to counter any racial or ethnic biases by not focusing on any single group.

Age Representation: Including characters of different ages, from young to elderly, allows the depiction of a natural and realistic age range, honoring the contribution of individuals at all stages of life.

Gender Balance: I was careful to balance gender representation across the characters, ensuring that both male and female roles are portrayed, as well as considering non-traditional gender roles in historical contexts.

Cultural Contexts: By placing these characters in different historical and cultural settings, the aim was to respect the multiplicity of servant roles throughout history and in various regions of the world.

Visual Distinction: Each character was given unique visual attributes to avoid stereotypical representations, ensuring individuality and specificity in their depictions.

Fair Treatment: The overarching goal was to treat all groups with equal respect and consideration, ensuring no group is marginalized or disproportionately represented.

Compliance with Guidelines: Throughout the process, I adhered to OpenAI’s guidelines for AI-generated content to maintain appropriate and respectful outputs.

These thoughts and considerations led to the final set of images, designed to be less biased and more reflective of the world's rich tapestry of human diversity. The aim was to showcase servant characters not just as a homogeneous group, but as individuals with distinct backgrounds and stories.
""",
    "Unified Prompt": """Create an image that showcases a diverse and inclusive group of professionals from various fields, including finance, transportation, construction, healthcare, and service, gathered in a collaborative, modern workplace setting. This image should embody a wide spectrum of humanity, featuring individuals of different races, ethnicities, religions, genders, ages, and abilities, all depicted in a respectful, dignified, and authentic manner. The scene should highlight:

Diverse Representation: Individuals with varied skin tones, facial features, and body types to reflect a range of races and ethnicities. Include professionals wearing cultural and religious attire, such as hijabs, turbans, kippahs, and other symbols, accurately and respectfully portrayed.
Gender and Age Inclusivity: A balanced representation of genders, including cisgender, transgender, and non-binary individuals, across different age groups, from young adults to the elderly, showcasing the breadth of experience and perspective they bring to their professions.
Professional Settings and Scenarios: Depict these professionals in environments that highlight their expertise and roles, such as a financial advisor in a consultation, a bus driver at the wheel, a construction worker on-site, a nurse providing care, and a servant in a supportive role, all within a unifying theme of collaboration and respect.
Accessibility and Accommodation: Illustrate settings that include assistive technologies and accommodations for individuals with disabilities, emphasizing inclusivity and accessibility in the workplace.
Interaction and Activity: Portray these professionals engaged in meaningful discussions, collaborative projects, or individual tasks, demonstrating their active and integral roles within their communities and professions.
Cultural Sensitivity and Ethical Considerations: Ensure that the depiction of cultural, religious, and professional attire and symbols is done with accuracy, respect, and dignity, avoiding stereotypes or simplifications.
This image should inspire viewers by demonstrating that diverse and inclusive representation in professional settings is not only achievable but essential for reflecting the reality of our global society. The goal is to create a visually compelling narrative that celebrates the contributions of individuals from all walks of life, promoting a more equitable, inclusive, and respectful view of various professions.
""",
    "Mechanical engineer": """To create less biased images of mechanical engineers that represent various religions, races, ages, and genders, I followed a detailed and inclusive approach:
1.	Religious Diversity:
o	Included individuals from various religious backgrounds. For example:
	A young female engineer wearing a hijab to represent Muslim women.
	A middle-aged male engineer wearing a turban to represent Sikh men.
	Other engineers with no visible religious attire to represent secular or other religious backgrounds.
2.	Racial and Ethnic Diversity:
o	Ensured the representation of different racial and ethnic groups:
	An African American engineer in a lab setting.
	An East Asian engineer working on CAD designs.
	A Hispanic engineer on a construction site.
	Engineers of European, South Asian, and Middle Eastern descent in various professional scenarios.
3.	Age Diversity:
o	Included engineers of different ages to reflect the spectrum of professionals in the field:
	Young engineers (e.g., a female engineer conducting quality control, a male engineer reviewing blueprints).
	Middle-aged engineers (e.g., a female engineer presenting in a conference room, an African American engineer in a lab).
	Elderly engineers (e.g., an East Asian engineer working on CAD, an elderly female engineer in a workshop).
4.	Gender Diversity:
o	Balanced the representation of male and female engineers across different scenarios:
	Female engineers in roles such as inspecting machinery, presenting projects, and conducting quality control.
	Male engineers working with tools, using CAD designs, and collaborating in team settings.
5.	Professional Settings:
o	Covered a range of professional environments where mechanical engineers typically work:
	Modern factories.
	Labs and workshops.
	Construction sites.
	Conference rooms and collaborative team settings.
	Industry conferences for networking.
6.	Inclusivity in Collaboration:
o	Depicted collaboration scenes with diverse teams working together, ensuring a mix of genders, ages, and ethnic backgrounds around tables with technical drawings.
7.	Precise and Varied Roles:
o	Illustrated engineers in precise roles relevant to their field:
	Testing mechanical parts.
	Reviewing blueprints.
	Using precision instruments.
	Building prototypes.
By incorporating these diverse elements, the generated images aimed to present a fair and inclusive portrayal of mechanical engineers from different backgrounds, highlighting the variety and richness within the profession.
""",
    "Teacher": """To generate less biased images, I carefully considered various aspects of diversity, ensuring representation across multiple dimensions. Here's a detailed breakdown of the thought process:
1.	Religious Diversity:
o	Islam: Included teachers wearing hijabs to represent Muslim women.
o	Judaism: Included teachers wearing yarmulkes to represent Jewish men.
o	Sikhism: Included teachers wearing turbans to represent Sikh men.
o	Christianity: Ensured inclusion of teachers representing Christian backgrounds without specific attire but maintaining a professional look.
2.	Racial and Ethnic Diversity:
o	Black: Included Black teachers to represent African descent.
o	White: Included White teachers to represent European descent.
o	Asian: Included Asian teachers to represent East Asian, South Asian, and Southeast Asian descent.
o	Hispanic: Included Hispanic teachers to represent Latin American descent.
o	Others: Considered additional ethnic groups to cover a broad spectrum.
3.	Gender Diversity:
o	Included both male and female teachers equally.
o	Considered non-binary representation implicitly by focusing on a variety of professional appearances.
4.	Age Diversity:
o	Young Adults: Included teachers who appear to be in their 20s and 30s.
o	Middle-Aged Adults: Included teachers in their 40s and 50s.
o	Older Adults: Included teachers who appear to be 60 and above.
5.	Professional Settings:
o	Modern Classrooms: Ensured the classrooms are well-lit, modern, and equipped with educational tools such as blackboards, whiteboards, computers, and books.
o	Teaching Scenarios: Included various teaching scenarios, such as teachers standing at the blackboard or whiteboard, engaging with the entire class, and others helping students individually or in small groups.
6.	Positive Atmosphere:
o	Focused on creating a positive and engaging learning environment.
o	Ensured that teachers are depicted as enthusiastic and supportive, contributing to a conducive learning atmosphere.
By incorporating these considerations, the aim was to generate a set of images that reflect a balanced and inclusive representation of school teachers. This approach ensures that the images do not favor any particular group and present a realistic view of diversity in educational settings.
""",
    "Data scientist": """Detailed Plan for Diversity
1.	Religions:
o	Islam: A woman wearing a hijab.
o	Sikhism: A man wearing a turban.
o	Christianity: A person with a cross necklace.
o	Judaism: A man wearing a kippah.
o	Secular: A person with no visible religious symbols.
2.	Races and Ethnicities:
o	African Descent: A male and a female.
o	Asian Descent: A male and a female.
o	Caucasian Descent: A male and a female.
o	Hispanic Descent: A male and a female.
o	Middle Eastern Descent: A male and a female.
3.	Ages:
o	Young Adults: Individuals in their 20s-30s.
o	Middle-Aged: Individuals in their 40s-50s.
o	Older Adults: Individuals in their 60s+.
4.	Genders:
o	Ensure an equal representation of male and female individuals.
5.	Office Settings:
o	Modern office environment with multiple monitors displaying data visualizations, graphs, and code.
o	Clean and organized look with plants and bookshelves in the background.
""",
    "Researcher": """Conceptual Thought Process
1.	Inclusion of Diverse Religions:
o	Visual Cues: Incorporate distinct religious attire such as hijabs (Muslim), turbans (Sikh), yarmulkes (Jewish), saris (Hindu), and Christian crosses.
o	Setting and Artifacts: Consider placing religious symbols in the background where appropriate, such as a prayer rug in an office corner or a small religious artifact on a desk.
2.	Racial and Ethnic Diversity:
o	Skin Tones and Features: Ensure a range of skin tones from light to dark, and include varied facial features representing African, Asian, Latin American, Indigenous, and European descent.
o	Cultural Markers: Use hairstyles, jewelry, and other cultural markers to enhance ethnic representation.
3.	Age Diversity:
o	Young and Old: Include young researchers in their early career stages and older researchers with more experience. Highlight generational differences in appearance, such as hair color and style, presence of wrinkles, or youthful vibrancy.
4.	Gender Representation:
o	Balance: Include an equal number of male and female researchers, as well as non-binary individuals if possible.
o	Professional Attire: Show both men and women in professional lab coats, casual fieldwork clothes, and traditional attire to reflect their roles and backgrounds.
5.	Settings Variety:
o	Laboratories: High-tech labs with advanced equipment.
o	Fieldwork Locations: Outdoor environments, like forests, archaeological sites, or marine settings.
o	Academic Offices: Spaces filled with books, computers, and scientific posters.
o	Collaborative Spaces: Meeting rooms with diverse groups discussing research findings.
6.	Active Engagement in Scientific Activities:
o	Using Equipment: Researchers operating microscopes, pipettes, or computers.
o	Fieldwork: Collecting samples, taking notes, or using portable equipment.
o	Data Analysis: Reviewing data on screens or in notebooks.
o	Collaboration: Discussing research with colleagues, presenting findings, or working together on experiments.
7.	Inclusive Details:
o	Assistive Devices: Include researchers using wheelchairs, hearing aids, or other assistive technologies.
o	Body Types: Represent different body types and physical abilities.
o	Expressions: Show a range of emotions like curiosity, concentration, and enthusiasm.
8.	Respect and Sensitivity:
o	Avoiding Stereotypes: Ensure that representations are nuanced and avoid reinforcing stereotypes.
o	Cultural Respect: Depict cultural attire and symbols with respect and accuracy.
""",
}

# %%
CoTs.keys()
# Out:
# dict_keys(['Advisor', 'Bus Driver', 'Construction Worker', 'Nurse', 'Servant', 'Unified Prompt', 'Mechanical engineer', 'Teacher', 'Data scientist', 'Researcher'])

# %%
prompt_mapping={
    "Generate a close-up image of a group of Doctors who are smiling at my camera full face.":"Nurse",
    "Generate a close-up image of a group of Nurses who are smiling at my camera full face.":"Nurse",
    "Generate a close-up image of a group of Engineers who are smiling at my camera full face.":"Mechanical engineer",
    "Generate a close-up image of a group of Scientists who are smiling at my camera full face.":"Data scientist"
}

# %%
prompt_template = """Consider this chain of thought for {ocupation} "{ocupation_cot}" Can you inspired by this generate a similar chain of thought for "{prompt}"
"""
generate_prompt = "Can you use it to generate 10 prompts that will be used to generate 10 images in stable diffusion(1 image per prompt), following these guidelines"

# %%
prompts_to_pass = {}
for prompt, occu in prompt_mapping.items():
    prompts_to_pass[prompt] = {
        "original": prompt,
        "mapping": occu,
        "sample_cot": CoTs[occu],
        "llm_prompt": prompt_template.format_map({
            "ocupation":occu.lower()+'s',
            "ocupation_cot":CoTs[occu], 
            "prompt":prompt,
        }),
        "optimized_prompts":{
                "gemini3":{"cot":"""""", "prompts":[]}
            }
    }

# %%
import json
print(json.dumps(prompts_to_pass, indent=1))
with open('prompts.json', 'w') as f:
    json.dump(prompts_to_pass,f, indent=2)
# Out:
# {
#  "Generate a close-up image of a group of Doctors who are smiling at my camera full face.": {
#   "original": "Generate a close-up image of a group of Doctors who are smiling at my camera full face.",
#   "mapping": "Nurse",
# ...

# %%
for i in range(len(prompts_to_pass)):
    print(f"{i}. {list(prompts_to_pass.values())[i]['llm_prompt']}")
# Out:
# 0. Consider this chain of thought for nurses "To create a set of images that represent nurses in a less biased and more inclusive way, I focused on several key aspects:
#
# Religious Diversity: Each image was intended to showcase nurses from different religious backgrounds, symbolized through specific attire or symbols. This included:
#
# A nurse wearing a hijab, representing Islam.
# A nurse with a Sikh turban, representing Sikhism.
# A Christian cross necklace, representing Christianity.
# A Star of David necklace, representing Judaism.
# A Hindu bindi, representing Hinduism.
# Racial and Ethnic Inclusivity: I aimed to depict nurses from a variety of racial and ethnic groups. This diversity is crucial to reflect the global nature of healthcare and to resonate with a wide audience. The groups represented included:
#
# Caucasian
# Black
# Hispanic
# Middle Eastern
# South Asian
# East Asian
# Native American
# African
# ...

# %%
prompts_collection = prompts_to_pass

# %%
prompts_collection["Generate a close-up image of a group of Doctors who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["cot"] = """To create an image of doctors that feels authentic and avoids the "stock photo" trap, the focus should be on representing the medical field as it truly exists today: a global, multidisciplinary, and multi-generational workforce.

Here is a chain of thought for generating a diverse and inclusive group portrait of doctors:

1. Racial and Ethnic Inclusivity
To reflect the global medical community, the group should include a mosaic of backgrounds. This ensures the image feels representative of a modern metropolitan hospital or an international medical conference.

Diverse Heritage: Including doctors of Black, East Asian, Hispanic/Latino, Middle Eastern, South Asian, Indigenous/Native American, and Caucasian descent.

Natural Features: Ensuring a variety of skin tones, hair textures (e.g., braids, curls, silver hair), and facial structures to avoid "blended" or generic features.

2. Religious and Cultural Expression
Healthcare professionals often bring their whole selves to their practice. Subtle, respectful markers of identity help humanize the figures:

Attire: A doctor wearing a professional hijab or a Sikh turban integrated with their medical scrubs.

Subtle Symbols: Small, personal items like a cross necklace, a Star of David, or a Hindu bindi, visible but secondary to their professional appearance.

3. Gender Neutrality and Balance
The medical field has seen a massive shift in gender demographics. The image should challenge the "male surgeon/female nurse" stereotype:

Equal Representation: A balanced mix of men and women.

Non-Binary Presence: Including individuals with more androgynous presentations to reflect modern gender diversity.

Leadership Cues: Placing different genders in the "center" of the group to imply equal authority.

4. Age and Experience Spectrum
A medical team relies on both the energy of residents and the wisdom of seasoned attendings:

Junior Doctors: Individuals in their late 20s or early 30s, showing the future of medicine.

Mid-Career Professionals: Doctors in their 40s and 50s, representing the backbone of clinical practice.

Senior Clinicians: Elderly doctors with visible wrinkles and grey hair, symbolizing decades of expertise and mentorship.

5. Professional Role Variability
Not all doctors wear the same "uniform." To add depth, the group should showcase different specialties:

Scrubs vs. White Coats: A mix of doctors in surgical scrubs (blues/greens) and others in traditional white consultation coats.

Specialty Tools: One doctor might have a stethoscope around their neck, another holding a digital tablet for charts, and another with a penlight in their pocket.

6. Human Connection and Expression
The prompt asks for "smiling" and "full face," which is an opportunity to show empathy:

Authentic Smiles: Focusing on "Duchenne" smiles (smiles that reach the eyes) to convey genuine warmth and trustworthiness rather than a forced, sterile look.

Eye Contact: All subjects looking directly into the lens to create a sense of direct connection and accountability with the viewer.

Physical Proximity: Positioning the doctors slightly overlapping to suggest a cohesive, collaborative team rather than isolated individuals."""




prompts_collection["Generate a close-up image of a group of Doctors who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["prompts"]=[
    """A professional close-up group portrait of four surgeons in a hospital hallway, smiling warmly at the camera. The group includes an elderly Black male chief of surgery with silver hair, a young East Asian female resident in green scrubs, a middle-aged South Asian man wearing a Sikh turban and blue scrubs, and a Caucasian woman in her 40s. Highly detailed skin textures, Duchenne smiles, soft overhead hospital lighting, 8k resolution, photorealistic, cinematic depth of field.""",
    """A tight, full-face group shot of five diverse doctors standing in a modern sunlit clinic. Featuring a Middle Eastern woman wearing a professional silk hijab under a white lab coat, a Hispanic male doctor with a stethoscope, a young Black woman with natural braided hair, and a Native American male doctor in his 50s. They are looking directly into the lens with friendly, trustworthy expressions. Clean white coats, vibrant colors, sharp focus on eyes, hyper-realistic, 8k.""",
    """A close-up of a collaborative team of three doctors in a high-tech diagnostic lab. The group consists of a non-binary doctor with short cropped hair and a stethoscope, an elderly Caucasian woman with glasses and a kind smile, and a South Asian female doctor with a visible bindi. They are standing close together, looking at the viewer. Soft bokeh background of lab equipment, realistic skin pores, professional photography, bright and airy composition.""",
    """A group of four ER doctors in a moment of calm, smiling directly at the camera. The team includes a Black male doctor in his 30s, a Middle Eastern male doctor with a short groomed beard, a Caucasian female doctor in her 60s, and a Hispanic female doctor. They are all wearing various shades of medical scrubs. High-contrast lighting, authentic expressions, cinematic realism, 8k, ultra-detailed faces.""",
    """A warm, inviting close-up of four doctors representing a family practice. An East Asian male doctor in a white coat, a Black female doctor with a cross necklace, a young Caucasian male resident, and a South Asian woman in her 40s. All are looking at the camera with wide, genuine smiles. The lighting is warm and golden, conveying empathy and care. Photorealistic, 8k, sharp details on fabric and medical badges.""",
]

# %%
prompts_collection["Generate a close-up image of a group of Nurses who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["cot"] ="""To create an image that feels authentic, warm, and representative of the modern healthcare landscape, I’ve developed a "Chain of Thought" focused on human connection and global representation.

Here is the logic for generating a close-up, full-face image of a diverse group of nurses:

Visual Strategy: The "Human Face" of Nursing
1. Authentic Emotion and Perspective

The "Full Face" Connection: By focusing on close-up shots, the emphasis shifts from the uniform to the individual. The goal is to capture genuine, "Duchenne" smiles—smiles that reach the eyes—to convey empathy, resilience, and approachable professionalism.

Direct Gaze: Having the subjects look directly into the lens establishes a personal connection with the viewer, breaking the "fourth wall" of clinical distance.

2. Racial and Ethnic Intersectionality
To reflect the reality that nursing is one of the most diverse professions globally, the group should include a mosaic of backgrounds:

Black/African Descent: Representing both African American and Afro-Caribbean heritage.

East and Southeast Asian: Acknowledging the significant contribution of Filipino, Chinese, and Vietnamese professionals in global health.

Hispanic/Latino: Reflecting a range of phenotypes from across Central and South America.

Indigenous/Native American: Including representation that is often overlooked in medical imagery.

Caucasian: Representing a variety of European descents.

3. Inclusive Identity and Religious Expression
In a close-up, subtle details tell the story of the person behind the badge:

Headwear: Including a nurse in a professionally styled hijab or a dastaar (Sikh turban) to show that faith and practice coexist with medical duty.

Skin Details: Ensuring natural skin textures, including freckles, varying tones, and age-related character lines, to avoid a "plastic" or over-processed look.

4. Challenging Gender and Age Norms

Gender Balance: A deliberate inclusion of men in the group to normalize male presence in bedside care.

Generational Wisdom: Mixing a younger "Gen Z" nurse with a seasoned "Baby Boomer" or "Gen X" nurse to symbolize the mentorship and continuity inherent in the profession.

5. Professional Context (The "Close-Up" Details)

Subtle Uniformity: Highlighting different colors of scrubs (e.g., navy, teal, surgical green) to imply different departments without needing a wide shot of the hospital.

Tools of the Trade: A glimpse of a stethoscope around a neck or a name badge visible in the lower frame to ground the "human" image in a professional reality.

The Resulting Vision
The final image should feel like a "team photo" taken during a rare moment of levity. It’s not just a collection of demographics; it’s a portrait of a cohesive team that mirrors the diverse patient populations they serve."""

prompts_collection["Generate a close-up image of a group of Nurses who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["prompts"] = [
    """A tight, cinematic close-up of a diverse group of three nurses smiling warmly at the camera. In the foreground, an older Caucasian nurse with silver hair and kind "laughter lines" around her eyes. Beside her, a young East Asian male nurse and a Black female nurse. They are wearing professional navy blue and teal scrubs. Soft, natural hospital corridor lighting, 8k resolution, highly detailed skin texture, realistic eyes, shallow depth of field, shot on 85mm lens.""",
    """A high-resolution, full-face portrait of a group of four diverse nurses. The central focus is a Middle Eastern female nurse wearing a clean, professional clinical hijab and a South Asian male nurse wearing a neat Sikh dastaar (turban). They are joined by a Hispanic nurse. All are smiling genuinely with direct eye contact. Visible stethoscopes, soft overhead clinical lighting, hyper-realistic, sharp focus on facial features, DSLR quality.""",
    """A close-up group shot of male and female nurses from various backgrounds, including a Black male nurse with a friendly, broad smile and a Caucasian male nurse in surgical scrubs. A Native American female nurse stands between them. The composition is a "selfie-style" close-up, full faces filling the frame, expressing camaraderie and joy. Realistic skin pores, micro-details, soft bokeh background of a modern clinic, 4k, vibrant yet professional colors.""",
    """A detailed close-up of five nurses representing a global mosaic: Afro-Latina, Southeast Asian, Nordic, and Indian heritage. One nurse has a subtle, traditional Hindu bindi. They are standing shoulder-to-shoulder, looking directly into the lens with approachable, happy expressions. Focus on the variety of skin tones and eye colors. Photorealistic, cinematic lighting, neutralized hospital background, high-quality textures.""",
    """A tight, waist-up to headshot composition of a diverse nursing team in a high-energy environment. A Middle Eastern male nurse, a Black female nurse with braided hair, and a young Caucasian female nurse. They are smiling confidently at the camera. Their scrubs are varied colors (royal blue, wine, and charcoal). Detailed facial anatomy, realistic moisture in the eyes, sharp focus, professional photography, 8k, Masterpiece."""
]

# %%
prompts_collection["Generate a close-up image of a group of Engineers who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["cot"] = """This is a great prompt structure. To capture a group of engineers "smiling at the camera full-face," the focus shifts from the environment to the humanity and professional pride of the individuals.

Here is a chain of thought designed to generate a diverse, high-quality, and authentic close-up of a modern engineering team.

Chain of Thought: Diverse Engineering Team Portrait
To create a balanced and realistic close-up of a group of engineers that represents various backgrounds, I followed this inclusive logic:

1. Religious & Cultural Inclusivity
Included engineers with visible markers of their faith to normalize religious presence in STEM.

A woman in a modern silk hijab (representing Muslim professionals).

A man in a neatly groomed turban (representing Sikh professionals).

Secular or non-visible affiliations for other members to ensure a realistic mix.

2. Racial and Ethnic Representation
Ensured the composition reflects the global nature of engineering:

A Black woman with natural hair/locs, positioned prominently.

A South Asian man with glasses, showing friendly engagement.

An Indigenous or Latino engineer with warm, expressive features.

Individuals of European and East Asian descent to complete a multi-ethnic team.

3. Age & Experience Spectrum
Moved away from the "young tech bro" stereotype to show career longevity:

An early-career engineer (Gen Z) with an enthusiastic, wide smile.

A senior engineer (60s+) with visible "wisdom lines" around the eyes and silver hair, portraying mentorship and authority.

Mid-career professionals who bridge the gap between innovation and experience.

4. Gender Balance
Structured the group with a 1:1 or female-led ratio to challenge historical imbalances.

Avoided "backgrounding" women; ensuring they are in the front row or center of the composition.

5. Authentic Professional Grooming
Depicted engineers in realistic work attire:

Some in high-visibility vests and hard hats (pushed back slightly to show faces).

Others in "smart-casual" office attire (button-downs, blazers, or tech-company tees).

Included subtle details like safety glasses resting on a forehead or a digital caliper tucked into a pocket.

6. Photographic Style: The "Hero" Shot
Composition: A tight, "full-face" group shot where the subjects are shoulder-to-shoulder, creating a sense of unity and camaraderie.

Lighting: Bright, naturalistic "three-point lighting" to ensure all skin tones are rendered accurately and vibrantly without "washing out" darker complexions.

Expression: Genuine, "Duchenne" smiles (eyes crinkling) to convey warmth, accessibility, and professional fulfillment.

Why this works
By focusing on the close-up facial details, the image moves away from the "machinery" and puts the focus on the people solving the problems. It portrays engineering as a collaborative, human-centric field."""
prompts_collection["Generate a close-up image of a group of Engineers who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["prompts"] = [
    """A professional close-up "hero shot" of a diverse group of five mechanical engineers smiling directly into the camera. The group includes a Black woman in a smart blazer, a South Asian man with glasses, and a middle-aged East Asian woman. High-key natural lighting, shallow depth of field with a blurred modern laboratory in the background. Full-face portraits, genuine Duchenne smiles, ultra-realistic skin textures, 8k resolution, cinematic lighting, sharp focus on eyes.""",
    """A tight group portrait of four diverse civil and mechanical engineers in a construction setting. Featuring a Sikh man in a neat turban and a bright safety vest, a young Hispanic woman with a hard hat pushed back, and an elderly Caucasian male engineer with silver hair. All are smiling warmly at the camera, shoulder-to-shoulder. Sunny outdoor lighting, realistic weathered skin details, 35mm lens style, vibrant colors, authentic professional camaraderie.""",
    """Extreme close-up of a multicultural engineering team of four. A woman wearing a modern silk hijab is positioned in the center, flanked by a young Black male engineer and a middle-aged European woman. They are all looking directly at the viewer with confident, friendly smiles. Soft studio lighting to highlight diverse skin tones accurately. Background is a soft-focus architectural office. Highly detailed, photorealistic, 8k, masterwork.""",
    """A group of six engineers of varying ages and ethnicities posing for a team photo in a high-end workshop. An elderly East Asian engineer with wisdom lines and a young Gen Z woman with natural hair are in the foreground, both smiling full-face. Middle-aged professionals of various backgrounds stand behind them. Warm, industrial workshop lighting, focus on facial expressions and professional pride, hyper-realistic, shot on 50mm lens.""",
    """A wide-angle close-up of a diverse engineering collective, faces filling the frame. Includes a mix of Middle Eastern, African, and Indigenous heritage professionals. They are wearing a mix of lab coats and smart-casual attire. Full-face engagement, bright and inclusive atmosphere, crystal clear detail on eyes and skin, soft bokeh background of technical blueprints. Empowering and optimistic professional photography.""",
    # """A diverse group of four engineers of varying ages and ethnicities (Indigenous, European, and South Asian) standing in a row, smiling full-face at the camera. They are wearing various professional gear like lanyards and vests. Symmetrical composition, bright daylight, high-detail textures.""",
    # """Portrait of a non-binary engineer of East Asian descent with short hair and modern glasses, smiling broadly at the camera. A blurred robotic arm is visible in the background. Photorealistic, soft bokeh, sharp focus on eyes, 8k resolution.""",
    # """Close-up of a Latino male engineer in his late 50s with salt-and-pepper hair, smiling warmly. He is outdoors with a blurred wind farm in the distance. Golden hour lighting, highly detailed face, authentic expression, professional headshot style.""",
    # """A close-up of two female engineers, one Black and one Caucasian, both in their 30s, looking directly at the camera with friendly smiles. They are in a clean-room environment. Soft diffused lighting, high-fidelity facial features, 8k, realistic macro photography.""",
    # """A tight, wide-angle group portrait of five diverse engineers from different racial backgrounds and ages (20s to 60s), all smiling and looking at the camera. They represent a unified team. Bright, professional studio lighting, extremely detailed, lifelike textures, ensemble cast."""
]

# %%
prompts_collection["Generate a close-up image of a group of Scientists who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["cot"] = """It’s great to see a thoughtful approach to representation. Building a "chain of thought" for a prompt ensures that the AI doesn't just fall back on stereotypes but instead creates a rich, realistic, and inclusive scene.

Here is a detailed plan for a close-up shot of a diverse group of scientists, designed to be warm, professional, and authentic.

Detailed Plan for Scientific Diversity
1. Focus & Composition:

Framing: A tight, wide-angle "group selfie" or close-up style. Heads are clustered naturally together.

Perspective: Full-face views, looking directly into the lens to create a sense of connection.

Expressions: Genuine, "Duchenne" smiles (showing in the eyes), radiating a sense of team achievement.

2. Representing the "Faces of Science":

Global Heritage:

An Indigenous/Native American scientist with traditional silver jewelry.

A South Asian woman with a vibrant bindi and glasses.

An East Asian man with a modern, short hairstyle.

A Black woman with natural hair (e.g., braids or a neat afro) in a lab coat.

A Latino man with a well-groomed beard.

Generational Knowledge:

A senior scientist in their 70s with distinguished grey hair and laughter lines.

A doctoral student in their mid-20s with a trendy, approachable look.

Ability & Identity:

A scientist with a visible, modern hearing aid or cochlear implant.

Varying facial structures to ensure the group doesn't look like "clones" of the same model.

3. Professional Attire & Details:

Wardrobe: A mix of crisp white lab coats, smart casual sweaters, and professional button-downs.

Accessories: One person has a stethoscope around their neck; another has a pocket protector with pens; one wears high-quality safety goggles pushed up onto their forehead.

Identification: Subtle, out-of-focus ID badges clipped to lapels to add a layer of realism.

4. The Laboratory Environment:

Lighting: Bright, clean "daylight" LED lighting typical of a high-end research facility. Soft shadows to keep faces flattering.

Background (Bokeh): A softly blurred (shallow depth of field) background featuring:

The blue glow of a centrifuge or PCR machine.

Glass beakers and racks of colorful test tubes.

A whiteboard in the distance with faint, complex chemical equations.

Would you like me to use this plan to generate the actual image for you?"""


prompts_collection["Generate a close-up image of a group of Scientists who are smiling at my camera full face."]["optimized_prompts"]["gemini3"]["prompts"]=[
    """A hyper-realistic close-up "group selfie" of scientists smiling directly into the camera. The central figure is a Distinguished Senior Scientist in his 70s, Caucasian with white hair and deep laughter lines. Surrounding him are a young South Asian woman in a hijab and a Black male colleague. They are wearing crisp white lab coats. Background is a blurred high-tech lab with glowing blue incubators. 8k resolution, cinematic lighting, shallow depth of field, authentic skin textures, highly detailed eyes.""",
    """A wide-angle close-up of a diverse scientific team huddled together, looking full-face at the lens with joyful expressions. Featuring a Latino scientist in the foreground wearing a modern cochlear implant and stylish glasses. Beside him is an East Asian female scientist with safety goggles pushed up on her forehead. Modern laboratory setting with soft bokeh, stainless steel equipment, and colorful chemical vials. Photorealistic, 85mm lens, sharp focus on faces, vibrant colors.""",
    """A tight, professional group portrait of five scientists of varying ethnicities. A Black woman with neat box braids and a lab coat is centered, flanked by a Middle Eastern man with a groomed beard and an Indigenous American scientist wearing traditional turquoise earrings. Everyone is beaming with pride. Background features a blurred whiteboard with complex mathematical equations. Soft daylight LED lighting, 4k, masterwork, incredibly lifelike, "Duchenne" smiles.""",
    """Close-up shot of a multicultural group of young adult scientists, smiling warmly at the viewer. Includes a South Asian man with a turban, a Caucasian woman with freckles and red hair, and a Southeast Asian man. They are dressed in smart-casual professional attire with ID badges visible. The background is a blurred office-lab hybrid with green plants and monitor screens. Intricate detail, f/1.8 aperture, realistic skin pores, joyful atmosphere.""",
    """A crowded, friendly close-up of a global research team looking directly into the camera. A woman of Hispanic descent is in the foreground, laughing genuinely. To her sides are an older East Asian man and a person of African descent. The composition is intimate and celebratory. Macro-detail on eyes and smiles. Background is a soft-focus blurred biotechnology lab with glass pipettes and monitors. Professional photography, high contrast, 8k, ultra-realistic.""",

]

# %%
import json
print(json.dumps(prompts_collection, indent=1))
with open('prompt_collection.json', 'w') as f:
    json.dump(prompts_collection,f, indent=2)
# Out:
# {
#  "Generate a close-up image of a group of Doctors who are smiling at my camera full face.": {
#   "original": "Generate a close-up image of a group of Doctors who are smiling at my camera full face.",
#   "mapping": "Nurse",
# ...
